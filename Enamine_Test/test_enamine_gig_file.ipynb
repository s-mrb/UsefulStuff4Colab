# %%
url = "https://enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_01.zip"

# %%
dwn_path = "/content/en"

# %%
# !wget "$url" -P "$dwn_path"

# %%
p = "/content/enamine.net/download/REAL/Enamine_REAL_full_smiles_Part_01.zip"
e = "/content/root/smiles/ena/"

# %%
# !unzip -uq "$p" -d "$e"

# %% [markdown]
# methods

# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit
# !time conda install -q -y -c openbabel openbabel

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

# %%
import openbabel

# %%
import pybel
from pybel import Outputfile
from pybel import readfile

# %%
# !pip install cairosvg

# %%
import ntpath
from os import walk, path
from pathlib import Path
import os
import sys





def feed_obabel(in_smile_path,out_svg_path):
  out_file = Outputfile("svg", out_svg_path)
  for mol in readfile("smi", in_smile_path):
    out_file.write(mol)
    
  out_file.close()




# define smiles feeder

def feed_smiles(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1
        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading smiles directory

    smiles_folders = getF(smiles, "folders")

    # Read
    for fol in smiles_folders:

        # current folder address
        current_folder_dir = smiles + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = r_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "smiles_feeder/")
            logs_path = root + "logs" + "/" + "smiles_feeder" + "/" + "sf_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call feed_obabel for this file only if it is not feeded already

            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    feed_obabel(file_path, out_path)
                    # after smiles2svg done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                feed_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)





def dir_check(path):
    Path(path).mkdir(parents=True, exist_ok=True)

# 2nd way
# def dir_check(path):
#     if not os.path.exists(path):
#         os.makedirs(path)


# here read_dict is used to read log files, make sure to keep all logs
# with same format so that you can reuse this function
def read_dict(path):
    dic = {}
    with open(path,'r') as f:
        key = ""
        for line in f:
            if line[0:5] == "_key_":
                key = (line.split())[1]
            else:
                temp = {key:line.split()}
                dic.update(temp)
        return dic

    # for line in file:
    #     line_offset.append(offset)
    #     offset += len(line)


def get_append_pos(path, key):
    with open(path,'r') as f:
        while True:
            # read line and move cursor to start of next line, but could be read in next while loop!!
            line = f.readline()

            if line == '':
                break
            if line[0:5] == "_key_":
                if (line.split())[1] == key:
                    # move cursor to start of **line after next line**,
                    # print()
                    f.readline()

                    # Why -1 works????
                    #
                    # The newline character is a single(typically 8 - bit) character.It's represented in program source
                    # (either in a character literal or in a string literal) by the two-character sequence \n . So '\n
                    # ' is a character constant representing a single character, the newline character

                    return f.tell() - 1
    return


def ap_dict(path, key, value, folder):
    # folder is boolean, 0 if key absent else 1
    if folder == 0:
        with open(path, 'a') as f:
            f.write("\n_key_ " + key + "\n" + value +" ")
            return
    pos = get_append_pos(path, key)

    c_last = ""

    with open (path, 'r') as f:
        f.seek(pos)
        c_last = f.read()

    # Note you can not use append below because
    # cause if first time if it is
    # _key_   gdb_11_2
    # gdb_11_2.txt
    #
    # then second time it will be
    # gdb_11_2.txt    gdb_11_3.txt    gdb_11_2.txt
    #
    # Why, because you r keeping line number to copy rest but using seek to write, so if you want to use append
    # then keep record of posiiton of index where to append
    #
    with open(path, 'a') as f:

        f.seek(pos)
        f.write(value + " " + c_last)



def file_if_not(p):
    if not os.path.exists(p):
        open(p, 'a').close()


def getF(directory, x="both"):
    # x could be "files" or "folders" or "both"

    folders = []
    for f in walk(directory):
        folders.extend(f)

    if x == "folders":

      return folders[1]
      
        
    if x == "files":
        return folders[2]
    else:
      return folders[1], folders[2]

      
        
        


def path_leaf(path):
    head, tail = ntpath.split(path)

    # if name ends with \\ then tail won't return anything
    # return tail or ntpath.basename(head)

    # since you dont want to return in case its not file
    return tail

def parse_r_obabel(read_path, write_path):
    # Parser for babel svg

    # NOTE below string also include \n, to add \n at end you must enter on last line
    start = """<svg version="1.1" id="topsvg"
    xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
    xmlns:cml="http://www.xml-cml.org/schema" x="0" y="0" width="256" height="256" viewBox="0 0 100 100">
    <title> - Open Babel Depiction</title>
    <rect x="0" y="0" width="100" height="100" fill="white"/>
    <g transform="translate(0,0)">
    """

    fil = 'fill="rgb(0,0,0)"'
    strke = 'stroke="rgb(0,0,0)"'
    strke_width = 'stroke-width="1"'

    # NOTE : anything added to above str is added on new line



    st = ""
    out = ""
    smile_done = False
    end = False
    finish = False
    space = " "
    width = 'width="100"'
    height = 'height="100"'

    test_c = 0
    dim_flag = False
    b_check = False
    s_check = False

    file = path_leaf(read_path)

    with open(read_path, 'r', encoding="utf-8") as f:
        for i in range(1):
            next(f)
        for line in f:
            if line[1:5] == "?xml":
              continue

            if line[1:12] == "svg version":
                for i in range(5):
                    next(f)
                continue
            if line[0:4] == "</g>" or end:

                end = True

                line_split = line.split()
                for token in line_split:
                    if token[0] == ">":
                        id = "db: " + file + " id: " + token[1:]
                        st = st + "</g>" + "\n" + "</svg>" + "\n"
                        st = id + "\n" + '"""' + "\n" + start + st + '"""' + "\n"
                        out = out + st
                        st = ""
                        smile_done = True
                        end = False

            if end:
                continue

            if smile_done:
                if not end:
                    smile_done = False
                    finish = True
                    continue
            if finish:
                finish = False

                continue

            token_list = []
            for s in line.split():
                if s[-1] == ">":
                    b_check = True

                if (2 <= len(s)):
                    if s[-2] == "/":
                        s_check = True

                if s[0:6] == "width=":
                    s = width
                if s[0:7] == "height=":
                    s = height
                if s[0:7] == "stroke=":
                    s = strke
                if s[0:13] == "stroke-width=":
                    s = strke_width
                if s[0:5] == "fill=":
                    s = fil
                if b_check:
                    b_check = False
                    if s_check:
                        s_check = False
                        if s[-2] != "/":
                            s = s + "/>"
                    elif s[-1] != ">":
                        s = s + ">"

                token_list.append(s)

            temp = ""
            for t in range(len(token_list) - 1):
                temp += token_list[t] + " "

            # sometimes list will  be empty
            if token_list:
                temp += token_list[-1] + "\n"

            token_list = []

            st = st + temp

    with open(write_path, 'w') as f:
        f.write(out)

# parse raw svg of obabel into form receivable to svg2png converter
def feed_parser(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")


    # g = getF(root + "\\" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("One folders missing!")

    if len(folders) == 2:
        raise Exception("Two folders missing!")
    if len(folders) == 3:
        raise Exception("Three folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1           

        

    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    # Reading r_obabel

    r_obabel_folders = getF(r_obabel, "folders")

    # Read
    for fol in r_obabel_folders:

        # current folder address
        current_folder_dir = r_obabel + fol + "/"

        # corresponding out folder for this folder
        corr_out_folder_dir = p_obabel + fol + "/"

        # files in current folder
        
        files = getF(current_folder_dir, "files")
    

        # do parsing of each file
        for fil in files:

            # complete path of current file
            file_path = current_folder_dir + fil

            dir_check(corr_out_folder_dir)

            # corresponding out file path
            # before passing file to parser make output folder if don't exist
            out_path = corr_out_folder_dir + fil

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "parser/")
            logs_path = root + "logs" + "/" + "parser" + "/" + "p_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call parser for this file only if it is not parsed already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    parse_r_obabel(file_path, out_path)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                parse_r_obabel(file_path, out_path)
                ap_dict(logs_path, fol, fil, 0)






def png_maker(current_file_path, cor_out_folder):
  
    input = current_file_path

    name = ""
    code = ""
    code_flag = False

    with open(current_file_path, 'r') as smiles:
        for line in smiles:
            if line[0:3] == "db:":
                tok = line.split()
                db = tok[1].split('.')[0]
                no = tok[3]
                name = db + "_" + no
                continue

            if line[0:3] == '"""':
                if code_flag:
                    code_flag = False

                    dir_check(cor_out_folder)
                    svg2png(bytestring=code,
                            write_to=cor_out_folder + name + ".png")

                    code = ""
                    name = ""
                    continue

            if line[0:3] == '"""':
                code_flag = True
                continue

            if code_flag:
                code += line




def feed_png_maker(root):

    if root[-1] != "/":
      root += "/"
    folders = getF(root, "folders")
    g = getF(root + "/" + folders[2])

    if len(folders) == 0:
        raise Exception("Empty directory!")

    if len(folders) == 1:
        raise Exception("Three folders missing!")

    if len(folders) == 2:
        raise Exception("two folders missing!")
    if len(folders) == 3:
        raise Exception("One folders missing!")

    r_obabel = ""
    r_png = ""
    p_obabel = ""
    smiles = ""

    flag = {"r_obabel": 0, "p_obabel": 0, "r_png": 0, "smiles":0}

    for f in folders:
        if f == "r_obabel":
            r_obabel = root + f + "/"
            flag["r_obabel"] = 1
        if f == "p_obabel":
            p_obabel = root + f + "/"
            flag["p_obabel"] = 1
        if f == "r_png":
            r_png = root + f + "/"
            flag["r_png"] = 1
        if f == "smiles":
            smiles = root + f + "/"
            flag["smiles"] = 1


    labels = list(flag.values())

    name = ""

    if not labels[0]:
        raise Exception("r_obabel folder not named properly!")
    if not labels[1]:
        raise Exception("p_obabel folder not named properly!")
    if not labels[2]:
        raise Exception("r_png folder not named properly")
    if not labels[3]:
        raise Exception("smiles folder not named properly")

    name = ""
    code = ""
    code_flag = False

    folders = getF(p_obabel, "folders")

    for fol in folders:

        current_folder_dir = p_obabel + fol + "/"
        files = getF(current_folder_dir, "files")

        for fil in files:

            current_file_path = current_folder_dir + fil
            cor_out_folder = r_png + fol + "/"

            # read log
            # if logs folder not present then make one
            dir_check(root + "logs" + "/" + "png_maker/")
            logs_path = root + "logs" + "/" + "png_maker" + "/" + "c_logs.txt"
            file_if_not(logs_path)
            logs_dict = read_dict(logs_path)

            # call png_maker for this file only if it is not done already
            # parser
            # if folder is in logs file
            # flag for file presence
            file_present = False

            if fol in logs_dict:
                # check whether file(i) is in it or not
                for i in logs_dict[fol]:
                    # if file found then continue
                    if i == fil:
                        file_present = True
                        continue
                if not file_present:
                    png_maker(current_file_path, cor_out_folder)
                    # after parsing done, record in logs
                    ap_dict(logs_path, fol, fil, 1)
            else:
                # print("folder not there")
                png_maker(current_file_path, cor_out_folder)
                ap_dict(logs_path, fol, fil, 0)

# %%
root = '/content/root/'

# %%
feed_smiles(root)

# %%
op = "/content/out/"
ip = "/content/ex/aa.smiles"

# %%
  out_file = Outputfile("svg", '/ab.txt')

  for mol in readfile("smi", '/content/one.smi'):
    print(mol)
    out_file.write(mol)
    
  out_file.close()

# %%
# !obabel -:"O=C(O)c1ccccc1OC(=O)C" -ocan
# Out:
# CC(=O)Oc1ccccc1C(=O)O
# 1 molecule converted

# %%
# !babel -ismi "$ip" -oxyz coronene.xyz
# Out:
# 0 molecules converted
# 5 audit log messages

# %%
# !babel -ismi '/content/one.smi' -osvg new.svg
# Out:
# 0 molecules converted
# 5 audit log messages

# %%
new_s = "/content/one.smi"

# %%
with open(ip,'r') as r:
  with open('/content/one.txt','w') as o:
    for l in r:
      o.write(l.split()[0]+"\n")

      
    
    # print(l)

# %%
with open (new_s,'r') as f:
  for l in f:
    print(l)
# Out:
# Streaming output truncated to the last 5000 lines.
# C=CCN1C(CC2=CC=CC(C#N)=C2C)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=CC=C3C=CC=NC3=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CCC(O)C2=CC=CC=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C(C)C2=CC=CN=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=CN=CC=N2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C(C)C2=CC=C(OC)C=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CNC(=O)CC)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2CCC3=C(C2)[NH]N=C3)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(N2CCC(C(=O)OC)CC2)=NN=C1C(C)(O)COC
#
# C=CCN1C(CC2CC(O)C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2C3CCCCC32)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(N2CCC(C(=O)OC)CC2)=NN=C1C1(C2=CC=CC=C2)CC1
#
# C=CCN1C(C2=NC(C)=NO2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CCC2=C[NH]C3=CC=CC=C23)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C(O)C2=CC=CC(OC)=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(COC2=CC=CN=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=C(C)OC=N2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=C(O)C3=CC=CN=C3S2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2CCC3(CC2)OCCO3)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C(O)CC)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=CC3=CC=CC=C3N2C)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CC(C)(O)C2=CC=CC=C2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CC2=CC=CO2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(N2CCC(C(=O)OC)CC2)=NN=C1C(C)(C)C(O)C1=CC=CC=C1
#
# C=CCN1C(C2=NN(C)C(C)=C2Cl)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=CC=C(C)N=C2C)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=NN(C3=CC=CC=C3)C=N2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=C(C)C=C(CO)O2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CN(C)CC2=CC=CC=N2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2CCCN2C(C)=O)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=C(C)[NH]N=C2C)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(CS(=O)(=O)C(C)(C)C)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=C(C)C=CO2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C(C2=NC3=CC=C(O)C=C3S2)=NN=C1N1CCC(C(=O)OC)CC1
#
# C=CCN1C
# C=CCN1C(CC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C(=O)NC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2=CC=C[NH]2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2=CC=CN2C)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(CO)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(CCCC)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC(C)=CC=C3C)CC2)=NN=C1C(C)(C)C
#
# C=CCN1C(C2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C(C)CC)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(CC2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2=COC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(COC)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(COCC)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2CCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2=CN(C)N=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2CCOC2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C2COCCO2)=NN=C1N1CCN(S(=O)(=O)C2=CC(C)=CC=C2C)CC1
#
# C=CCN1C(C)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(Br)C=C2)CC1
#
# C=CCN1C(CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(Br)C=C2)CC1
#
# C=CCN1C(C)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(C2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(C2=CC=CO2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(C(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(CC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=C([N+](=O)[O-])C=C2)CC1
#
# C=CCN1C(CC2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC([N+](=O)[O-])=CC=C2)CC1
#
# C=CCN1C(C2=COC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC([N+](=O)[O-])=CC=C2)CC1
#
# C=CCN1C(CC(C)(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC([N+](=O)[O-])=C2)CC1
#
# C=CCN1C(COC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC([N+](=O)[O-])=C2)CC1
#
# C=CCN1C(COCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC([N+](=O)[O-])=C2)CC1
#
# C=CCN1C(C2CCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC([N+](=O)[O-])=CC=C2)CC1
#
# C=CCN1C(C2CCOC2)=NN=C1N1CCN(S(=O)(=O)C2=CC([N+](=O)[O-])=CC=C2)CC1
#
# C=CCN1C(C2=CC=CC=N2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CC=C2Cl)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CN=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(Cl)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCOC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(C)C=C2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=C(C)OC(C)=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(OC)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=C(C)OC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC(Cl)=CC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(C)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CO2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CS2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2=CC=CC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2CCCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(CC)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CN2N=C(C)C=C2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2=CC=C(F)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CC=C2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(=O)NC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C[NH]2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CN2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC([N+](=O)[O-])=C[NH]2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC(C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2=CSC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(F)F)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC=CS3)CC2)=NN=C1C(C)(C)O
#
# C=CCN1C(C(O)C=C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CC=C2OC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CO)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC=CS3)CC2)=NN=C1C(C)(C)C
#
# C=CCN1C(C2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(C)CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=NC(C)=CC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCO)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=COC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(=O)N2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCC2=CC=CO2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(C#N)C=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CCC2=CC=CC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2CC2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC(C)(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2CCCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=C(C)C=CS2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C([C@H](C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=CC(C#N)=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2=CC=CC=N2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C([C@@H](C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C[C@H](C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C[C@@H](C)O)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(COC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CC2=CC=CC=C2F)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(COCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC=CS3)CC2)=NN=C1C1(O)CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC=CS3)CC2)=NN=C1C(C)(C)F
#
# C=CCN1C(C2CCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CN(C)N=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=CC=C(C)O2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2CCOC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C(O)CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(C2=NC=CC=C2C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
# C=CCN1C(CSC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CS2)CC1
#
#
# C=CCN1C(C(C)CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(CC2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2=COC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(CC2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(CC(C)(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(COC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(COCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2CCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2=CN(C)N=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2=CC=C(C)O2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2CCOC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C2COCCO2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(OC)C=C2)CC1
#
# C=CCN1C(C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C2=CC=CO2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(CC(C)C)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C2=CC=C[NH]2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(CCCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(N2CCN(S(=O)(=O)C3=CC=CC=C3[N+](=O)[O-])CC2)=NN=C1C(C)(C)C
#
# C=CCN1C(C2CCCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C(C)CC)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(CC2CC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=CC=C2[N+](=O)[O-])CC1
#
# C=CCN1C(C2=COC=C2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(C(C)C)C=C2)CC1
#
# C=CCN1C(COC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(C(C)C)C=C2)CC1
#
# C=CCN1C(COCC)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(C(C)C)C=C2)CC1
#
# C=CCN1C(C2CCC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(C(C)C)C=C2)CC1
#
# C=CCN1C(C2CCOC2)=NN=C1N1CCN(S(=O)(=O)C2=CC=C(C(C)C)C=C2)CC1
#
# C=CCN1C(C2=CC=C([N+](=O)[O-])C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CC=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CC([N+](=O)[O-])=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)N=C[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(N)=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CN=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CCOC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCCN(C)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(OC)C(OC)=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2COC3=CC=CC=C3O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)OC(C)=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(COC2=CC=C(C#N)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(COC2=CC=CC=C2F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)OC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC(S(=O)(=O)N(C)C)=CC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CO2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CS2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=CC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN(CC)C(=O)C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN(C)C(=O)C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=N[NH]C(=O)C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN(C(C)C)C(=O)C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN(CCC)C(=O)C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NOC(C)=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)OC2=CC=CC=C2F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=C[NH]C3=CC=CC=C23)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)N=C(N3CCOCC3)S2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CSC(N3CCOCC3)=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2N=C(C)C=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(N3C=NN=N3)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=C(F)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCCC2=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCCCCC2=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=C(OC)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(=O)NC(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=NC(C)=CS2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CN2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC(Br)=C[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC([N+](=O)[O-])=C[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=N[NH]N=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2CCS(=O)(=O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCS(=O)(=O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=C(C)[NH]N=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC(C)=N[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C[N+](=O)[O-])=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC(C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)CO)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)[N+](=O)[O-])=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CSC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(F)F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(C)O
#
# C=CCN1C(C(O)C=C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CC=C2OC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CS(C)=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CO)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CS(C)(=O)=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CCCC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC(C)=N[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(C)C
#
# C=CCN1C(C2CCCC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CC(S(C)(=O)=O)=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)CC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCC(O)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(Cl)N=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NOC=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=NC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CCN2C=CN=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCCC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(C)C#N
#
# C=CCN1C(C2=CC=CC(C)=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC(F)(F)F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=NC=CN2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CCO)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCC(C(N)=O)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCN(C)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C([C@H](C)NS(C)(=O)=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=CC=C2OC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CNC(=O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C1(C#N)CCOCC1
#
# C=CCN1C(CCCC#N)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC3=CC=CC=C3O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=COC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(=O)N2CCCC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CCC2=CC=CO2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CNC(=O)C2=CC=CS2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(C#N)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)N=CS2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C([C@H](C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)NS(C)(=O)=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=NC(C)=NO2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(S(C)(=O)=O)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=CC(C#N)=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2C=CC3=CC=CC=C32)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCN(C3=NC=CC=N3)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NC=CN2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=CN=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=CC=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(OC)C(OC)=CC=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C([C@@H](C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C[C@H](O)CC#N)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C[C@H](C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C[C@@H](C)O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(F)F
#
# C=CCN1C(C2=C(C(F)F)[NH]N=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC(F)F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCC(O)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCCC(O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(OC)C=C2OC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=N[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN=C[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2CCC(CO)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(COC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CC=CC=C2F)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(COCC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C1(O)CC1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(C)F
#
# C=CCN1C(C2=COC(C)=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NC=CC=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCN(C(=O)OC(C)(C)C)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CN=C3ON=C(C)C3=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC(O)C2=CC=CN=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCCCC2O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC(=O)N(C)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC(O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CN=C(O)N=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2SCCNC2=O)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=NC=N[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN=C(C)S2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)N=C(C)O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CN=N[NH]2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NN=C(C)O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC(=O)N(CC)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C([C@@H](O)C(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NC=C(C)O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(N)[NH]N=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2CCNC(=O)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCC3=C(C=N[NH]3)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C(C)[NH]N=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=CSC=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CC2=N[NH]C(C)=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NOC(CO)C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CN(C)N=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(O)CC(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(O)CC
#
# C=CCN1C(CC(C)SC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(C)SC)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(=O)NC2=CC=CC=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCC(=O)N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCN(CCO)CC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CC=NO2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C1(C#N)CC=CC1
#
# C=CCN1C(C2=C[NH]C(=O)C=C2C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C(O)C(C)C)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC(=O)N(C)C=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=C[NH]C(C)=N2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=CC=C(C)O2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2CCOCC2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(CN2C=CN=C2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(C2=NC(CO)=CS2)=NN=C1N(C)CCOC1=CC=CC=C1
#
# C=CCN1C(N(C)CCOC2=CC=CC=C2)=NN=C1C(C)(C)CC#N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-2da8edf36479> in <module>()
#       1 with open (new_s,'r') as f:
#       2   for l in f:
# ----> 3     print(l)
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     396                 string = string.decode(self.encoding, 'replace')
#     397
# --> 398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
#     400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     306
#     307     def _is_master_process(self):
# --> 308         return os.getpid() == self._master_pid
#     309
#     310     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
with open ('/gdb11_size03.smi', 'r') as f:
  for l in f:
    print (l)
# Out:
# CCC
#
# CCN
#
# CCO
#
# CCF
#
# FCF
#
# CNC
#
# COC
#
# CC=C
#
# CC=O
#
# CC#N
#
# NC=N
#
# NC=O
#
# OC=O
#
# FC=C
#
# NN=C
#
# ON=C
#
# CC#C
#
# C1CC1
#
# C1CN1
#
# C1CO1
